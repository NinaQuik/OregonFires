# %%
# SQLAlchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect

# Pandas
import pandas as pd
from datetime import datetime

# Path to sqlite
database_path = "Resources/FPA_FOD_20170508.sqlite"

import os

import psycopg2

from config import db_password

# %%
# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")

# %%
# Get the name of the tables. 
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['ElementaryGeometries',
#  'Fires',
#  'KNN',
#  'NWCG_UnitIDActive_20170109',
#  'SpatialIndex',
#  'geometry_columns',
#  'geometry_columns_auth',
#  'geometry_columns_field_infos',
#  'geometry_columns_statistics',
#  'geometry_columns_time',
#  'idx_Fires_Shape',
#  'idx_Fires_Shape_node',
#  'idx_Fires_Shape_parent',
#  'idx_Fires_Shape_rowid',
#  'spatial_ref_sys',
#  'spatial_ref_sys_aux',
#  'spatialite_history',
#  'sql_statements_log',
#  'sqlite_sequence',
#  'views_geometry_columns',
#  'views_geometry_columns_auth',
#  'views_geometry_columns_field_infos',
#  'views_geometry_columns_statistics',
#  'virts_geometry_columns',
#  'virts_geometry_columns_auth',
#  'virts_geometry_columns_field_infos',
#  'virts_geometry_columns_statistics']

# %%
# Using the inspector to print the column names within the 'Fires' table
columns = inspector.get_columns('Fires')
for column_name in columns:
    print(column_name["name"])
# Out:
# OBJECTID
# FOD_ID
# FPA_ID
# SOURCE_SYSTEM_TYPE
# SOURCE_SYSTEM
# NWCG_REPORTING_AGENCY
# NWCG_REPORTING_UNIT_ID
# NWCG_REPORTING_UNIT_NAME
# SOURCE_REPORTING_UNIT
# SOURCE_REPORTING_UNIT_NAME
# LOCAL_FIRE_REPORT_ID
# LOCAL_INCIDENT_ID
# FIRE_CODE
# FIRE_NAME
# ICS_209_INCIDENT_NUMBER
# ICS_209_NAME
# MTBS_ID
# MTBS_FIRE_NAME
# COMPLEX_NAME
# FIRE_YEAR
# DISCOVERY_DATE
# DISCOVERY_DOY
# DISCOVERY_TIME
# STAT_CAUSE_CODE
# STAT_CAUSE_DESCR
# CONT_DATE
# CONT_DOY
# CONT_TIME
# FIRE_SIZE
# FIRE_SIZE_CLASS
# LATITUDE
# LONGITUDE
# OWNER_CODE
# OWNER_DESCR
# STATE
# COUNTY
# FIPS_CODE
# FIPS_NAME
# Shape

# %%
# Make a connection to the SQL database
conn = engine.connect()

# %%
# Filter out fires - include only fires in Oregon
fire_data_df = pd.read_sql("SELECT * FROM Fires WHERE State = 'OR'", conn)
fire_data_df
# Out:
#        OBJECTID     FOD_ID                   FPA_ID SOURCE_SYSTEM_TYPE  \
# 0            32         32               FS-1418907                FED
# 1            36         36               FS-1418916                FED
# 2            44         44               FS-1418924                FED
# 3            47         47               FS-1418935                FED
# 4            49         49               FS-1418943                FED
# ...         ...        ...                      ...                ...
# 61083   1847484  300273935  SFO-2015ORODF1578108416             NONFED
# 61084   1847532  300274008  SFO-2015ORODF1572111916             NONFED
# 61085   1849328  300276174  SFO-2015ORODF1595505916             NONFED
# 61086   1859995  300293828      ICS209_2015_2813572          INTERAGCY
# 61087   1860058  300293911      ICS209_2015_2947050          INTERAGCY
#
#       SOURCE_SYSTEM NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 0       FS-FIRESTAT                    FS                USORDEF
# 1       FS-FIRESTAT                    FS                USORDEF
# 2       FS-FIRESTAT                    FS                USORDEF
# 3       FS-FIRESTAT                    FS                USORUMF
# 4       FS-FIRESTAT                    FS                USORDEF
# ...             ...                   ...                    ...
# 61083       ST-NASF                ST/C&L                USORORS
# 61084       ST-NASF                ST/C&L                USORORS
# 61085       ST-NASF                ST/C&L                USORORS
# 61086     IA-ICS209                   BLM                USORPRD
# 61087     IA-ICS209                    FS                USORCGF
#
#                                NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 0                             Deschutes National Forest                  0601
# 1                             Deschutes National Forest                  0601
# 2                             Deschutes National Forest                  0601
# 3                              Umatilla National Forest                  0614
# 4                             Deschutes National Forest                  0601
# ...                                                 ...                   ...
# 61083  Oregon Department of Forestry State Headquarters                 ORODF
# 61084  Oregon Department of Forestry State Headquarters                 ORODF
# 61085  Oregon Department of Forestry State Headquarters                 ORODF
# 61086                               Prineville District                 ORPRD
# 61087         Columbia River Gorge National Scenic Area                 ORCGF
#
#                       SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 0                      Deschutes National Forest  ...               A
# 1                      Deschutes National Forest  ...               A
# 2                      Deschutes National Forest  ...               A
# 3                       Umatilla National Forest  ...               B
# 4                      Deschutes National Forest  ...               A
# ...                                          ...  ...             ...
# 61083              Oregon Department of Forestry  ...               A
# 61084              Oregon Department of Forestry  ...               A
# 61085              Oregon Department of Forestry  ...               A
# 61086                        Prineville District  ...               E
# 61087  Columbia River Gorge National Scenic Area  ...               E
#
#         LATITUDE   LONGITUDE OWNER_CODE            OWNER_DESCR STATE  \
# 0      43.995556 -121.414167       13.0       STATE OR PRIVATE    OR
# 1      44.043333 -121.386111        5.0                   USFS    OR
# 2      43.955556 -121.352222        5.0                   USFS    OR
# 3      44.911111 -119.696111        5.0                   USFS    OR
# 4      43.725278 -121.574167        5.0                   USFS    OR
# ...          ...         ...        ...                    ...   ...
# 61083  43.971670 -124.100280        8.0                PRIVATE    OR
# 61084  43.343330 -124.197500        8.0                PRIVATE    OR
# 61085  44.003330 -121.321670        8.0                PRIVATE    OR
# 61086  44.526700 -121.389700       14.0  MISSING/NOT SPECIFIED    OR
# 61087  45.611100 -122.011200        5.0                   USFS    OR
#
#                  COUNTY FIPS_CODE  FIPS_NAME  \
# 0                    17       017  Deschutes
# 1                    17       017  Deschutes
# 2                    17       017  Deschutes
# 3                    69       069    Wheeler
# 4                    17       017  Deschutes
# ...                 ...       ...        ...
# 61083              Lane       039       Lane
# 61084              Coos       011       Coos
# 61085         Deschutes       017  Deschutes
# 61086  Jefferson County       031  Jefferson
# 61087  Multnomah County       051  Multnomah
#
#                                                    Shape
# 0      b'\x00\x01\xad\x10\x00\x00\x90\xaf\xeb\xb4\x81...
# 1      b'\x00\x01\xad\x10\x00\x00\x9c\x84_\x0b\xb6X^\...
# 2      b'\x00\x01\xad\x10\x00\x00\xc4\xf4\x10\xcf\x8a...
# 3      b'\x00\x01\xad\x10\x00\x00@\xf5\x9c\x15\x8d\xe...
# 4      b'\x00\x01\xad\x10\x00\x00\x98\x86\x8f%\xbfd^\...
# ...                                                  ...
# 61083  b'\x00\x01\xad\x10\x00\x00T\x1c\xce\xfcj\x06_\...
# 61084  b'\x00\x01\xad\x10\x00\x00p=\n\xd7\xa3\x0c_\xc...
# 61085  b'\x00\x01\xad\x10\x00\x00\xac\x86\xc4=\x96T^\...
# 61086  b'\x00\x01\xad\x10\x00\x00\x10\xd0D\xd8\xf0X^\...
# 61087  b'\x00\x01\xad\x10\x00\x00\xc4m4\x80\xb7\x80^\...
#
# [61088 rows x 39 columns]

# %%
#What are the data types
fire_data_df.dtypes
# Out:
# OBJECTID                        int64
# FOD_ID                          int64
# FPA_ID                         object
# SOURCE_SYSTEM_TYPE             object
# SOURCE_SYSTEM                  object
# NWCG_REPORTING_AGENCY          object
# NWCG_REPORTING_UNIT_ID         object
# NWCG_REPORTING_UNIT_NAME       object
# SOURCE_REPORTING_UNIT          object
# SOURCE_REPORTING_UNIT_NAME     object
# LOCAL_FIRE_REPORT_ID           object
# LOCAL_INCIDENT_ID              object
# FIRE_CODE                      object
# FIRE_NAME                      object
# ICS_209_INCIDENT_NUMBER        object
# ICS_209_NAME                   object
# MTBS_ID                        object
# MTBS_FIRE_NAME                 object
# COMPLEX_NAME                   object
# FIRE_YEAR                       int64
# DISCOVERY_DATE                float64
# DISCOVERY_DOY                   int64
# DISCOVERY_TIME                 object
# STAT_CAUSE_CODE               float64
# STAT_CAUSE_DESCR               object
# CONT_DATE                     float64
# CONT_DOY                      float64
# CONT_TIME                      object
# FIRE_SIZE                     float64
# FIRE_SIZE_CLASS                object
# LATITUDE                      float64
# LONGITUDE                     float64
# OWNER_CODE                    float64
# OWNER_DESCR                    object
# STATE                          object
# COUNTY                         object
# FIPS_CODE                      object
# FIPS_NAME                      object
# Shape                          object
# dtype: object

# %%
# Create a dataFrame with the useful columns for this analysis
oregon_fires_df = fire_data_df[["FOD_ID","FIRE_NAME","FIRE_SIZE","FIRE_SIZE_CLASS", "LATITUDE", "LONGITUDE", "FIRE_YEAR", "DISCOVERY_DATE", "DISCOVERY_DOY", "CONT_DATE", "CONT_DOY", "STAT_CAUSE_CODE", "STAT_CAUSE_DESCR", "FIPS_CODE", "FIPS_NAME"]]
oregon_fires_df.head(20)
# Out:
#     FOD_ID          FIRE_NAME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0       32               0028       0.10               A  43.995556
# 1       36               0044       0.10               A  44.043333
# 2       44               0088       0.10               A  43.955556
# 3       47              EARLY       5.00               B  44.911111
# 4       49               0032       0.10               A  43.725278
# 5       50               0041       0.10               A  44.410000
# 6       51       HALFWAY  108       0.10               A  42.133889
# 7       52      PARADISE  104       0.10               A  42.311389
# 8       53          STUMP 106       0.10               A  42.950833
# 9       56    COTTONWOOD  128       0.10               A  42.386944
# 10      57     OBENCHAIN  125       2.00               B  42.514722
# 11      60        JUNIOR  122       0.10               A  42.921389
# 12      69  THOMAS CREEK  126       0.10               A  42.302778
# 13      70           DOG  129       0.50               B  42.136944
# 14      80      SMITH RIDGE 1       0.10               A  45.554444
# 15      91      DUNCANS RIDGE       0.10               A  44.988611
# 16      95          SNAG  124       0.10               A  42.620833
# 17     115              #2029       1.00               B  43.991389
# 18     121         RODEO FIRE       0.10               A  43.783333
# 19     129        CRAFT CABIN       0.25               A  43.808889
#
#      LONGITUDE  FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  CONT_DATE  CONT_DOY  \
# 0  -121.414167       2005       2453406.5             36  2453407.5      37.0
# 1  -121.386111       2005       2453434.5             64  2453434.5      64.0
# 2  -121.352222       2005       2453465.5             95  2453465.5      95.0
# 3  -119.696111       2005       2453440.5             70  2453440.5      70.0
# 4  -121.574167       2005       2453417.5             47  2453417.5      47.0
# 5  -121.315556       2005       2453431.5             61  2453431.5      61.0
# 6  -121.234167       2005       2453518.5            148  2453518.5     148.0
# 7  -120.902778       2005       2453507.5            137  2453507.5     137.0
# 8  -120.836111       2005       2453517.5            147  2453517.5     147.0
# 9  -120.808611       2005       2453546.5            176  2453547.5     177.0
# 10 -121.120000       2005       2453546.5            176  2453546.5     176.0
# 11 -121.030833       2005       2453545.5            175  2453545.5     175.0
# 12 -120.543611       2005       2453546.5            176  2453546.5     176.0
# 13 -120.701667       2005       2453547.5            177  2453547.5     177.0
# 14 -118.101944       2005       2453539.5            169  2453540.5     170.0
# 15 -118.938889       2005       2453542.5            172  2453542.5     172.0
# 16 -120.845000       2005       2453546.5            176  2453546.5     176.0
# 17 -118.732778       2005       2453527.5            157  2453528.5     158.0
# 18 -119.000000       2005       2453534.5            164  2453534.5     164.0
# 19 -118.727500       2005       2453540.5            170  2453540.5     170.0
#
#     STAT_CAUSE_CODE STAT_CAUSE_DESCR FIPS_CODE  FIPS_NAME
# 0               4.0         Campfire       017  Deschutes
# 1               4.0         Campfire       017  Deschutes
# 2               4.0         Campfire       017  Deschutes
# 3               9.0    Miscellaneous       069    Wheeler
# 4               4.0         Campfire       017  Deschutes
# 5               5.0   Debris Burning       017  Deschutes
# 6               1.0        Lightning       037       Lake
# 7               9.0    Miscellaneous       037       Lake
# 8               7.0            Arson       037       Lake
# 9               1.0        Lightning       037       Lake
# 10              1.0        Lightning       037       Lake
# 11              1.0        Lightning       037       Lake
# 12              1.0        Lightning       037       Lake
# 13              1.0        Lightning       037       Lake
# 14              1.0        Lightning       061      Union
# 15              1.0        Lightning       023      Grant
# 16              1.0        Lightning       037       Lake
# 17              1.0        Lightning       025     Harney
# 18              4.0         Campfire       025     Harney
# 19              1.0        Lightning       025     Harney

# %%
# See what data is missing
oregon_fires_df.count()
# Out:
# FOD_ID              61088
# FIRE_NAME           56970
# FIRE_SIZE           61088
# FIRE_SIZE_CLASS     61088
# LATITUDE            61088
# LONGITUDE           61088
# FIRE_YEAR           61088
# DISCOVERY_DATE      61088
# DISCOVERY_DOY       61088
# CONT_DATE           60751
# CONT_DOY            60751
# STAT_CAUSE_CODE     61088
# STAT_CAUSE_DESCR    61088
# FIPS_CODE           40178
# FIPS_NAME           40178
# dtype: int64

# %%
# Drop fires that don't have a containment date
oregon_fires_df = oregon_fires_df.dropna(subset=["CONT_DATE","CONT_DOY"], how='all')
oregon_fires_df.count()
# Out:
# FOD_ID              60751
# FIRE_NAME           56633
# FIRE_SIZE           60751
# FIRE_SIZE_CLASS     60751
# LATITUDE            60751
# LONGITUDE           60751
# FIRE_YEAR           60751
# DISCOVERY_DATE      60751
# DISCOVERY_DOY       60751
# CONT_DATE           60751
# CONT_DOY            60751
# STAT_CAUSE_CODE     60751
# STAT_CAUSE_DESCR    60751
# FIPS_CODE           39916
# FIPS_NAME           39916
# dtype: int64

# %%
oregon_fires_df.tail()
# Out:
#           FOD_ID              FIRE_NAME  FIRE_SIZE FIRE_SIZE_CLASS  LATITUDE  \
# 61081  300273801  OLD PORTLAND/KASTER#3       0.01               A  45.85047
# 61082  300273869          WINHURST LANE       0.10               A  43.09000
# 61083  300273935           MUNSEL CREEK       0.01               A  43.97167
# 61084  300274008         MP 240 HWY 101       0.01               A  43.34333
# 61085  300276174          CHINA HAT 698       0.10               A  44.00333
#
#        LONGITUDE  FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  CONT_DATE  \
# 61081 -122.81353       2015       2457292.5            270  2457292.5
# 61082 -124.39028       2015       2457293.5            271  2457294.5
# 61083 -124.10028       2015       2457297.5            275  2457297.5
# 61084 -124.19750       2015       2457299.5            277  2457300.5
# 61085 -121.32167       2015       2457357.5            335  2457360.5
#
#        CONT_DOY  STAT_CAUSE_CODE STAT_CAUSE_DESCR FIPS_CODE  FIPS_NAME
# 61081     270.0              9.0    Miscellaneous       009   Columbia
# 61082     272.0              9.0    Miscellaneous       011       Coos
# 61083     275.0              9.0    Miscellaneous       039       Lane
# 61084     278.0              9.0    Miscellaneous       011       Coos
# 61085     338.0              9.0    Miscellaneous       017  Deschutes

# %%
#Explore causes of fires
oregon_fires_df["STAT_CAUSE_DESCR"].value_counts()
# Out:
# Lightning            31329
# Campfire              7418
# Debris Burning        5067
# Miscellaneous         4907
# Equipment Use         4720
# Smoking               2295
# Arson                 1822
# Children              1175
# Missing/Undefined      808
# Fireworks              600
# Railroad               314
# Powerline              215
# Structure               81
# Name: STAT_CAUSE_DESCR, dtype: int64

# %%
#Explore counties where fires are reported
oregon_fires_df["FIPS_NAME"].value_counts(dropna=False)
# Out:
# NaN           20835
# Jackson        3650
# Klamath        3541
# Douglas        3532
# Deschutes      3251
# Lane           2944
# Grant          2588
# Josephine      2530
# Lake           1689
# Clackamas      1438
# Harney         1188
# Crook          1184
# Wallowa         948
# Umatilla        947
# Baker           919
# Coos            912
# Linn            815
# Wasco           761
# Union           722
# Wheeler         678
# Malheur         672
# Marion          505
# Hood River      496
# Jefferson       442
# Clatsop         414
# Morrow          411
# Tillamook       409
# Curry           395
# Columbia        372
# Lincoln         339
# Yamhill         305
# Benton          277
# Washington      247
# Polk            215
# Multnomah        99
# Sherman          43
# Gilliam          38
# Name: FIPS_NAME, dtype: int64

# %%
# Convert those Julian!!?? dates into normal dates
oregon_fires_df["DISCOVER_DATE"] = pd.to_datetime(oregon_fires_df["DISCOVERY_DATE"], unit='D', origin='julian')
oregon_fires_df["CONTAINMENT_DATE"] = pd.to_datetime(oregon_fires_df["CONT_DATE"], unit='D', origin='julian')
oregon_fires_df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 0      32      0028        0.1               A  43.995556 -121.414167
# 1      36      0044        0.1               A  44.043333 -121.386111
# 2      44      0088        0.1               A  43.955556 -121.352222
# 3      47     EARLY        5.0               B  44.911111 -119.696111
# 4      49      0032        0.1               A  43.725278 -121.574167
#
#    FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  CONT_DATE  CONT_DOY  \
# 0       2005       2453406.5             36  2453407.5      37.0
# 1       2005       2453434.5             64  2453434.5      64.0
# 2       2005       2453465.5             95  2453465.5      95.0
# 3       2005       2453440.5             70  2453440.5      70.0
# 4       2005       2453417.5             47  2453417.5      47.0
#
#    STAT_CAUSE_CODE STAT_CAUSE_DESCR FIPS_CODE  FIPS_NAME DISCOVER_DATE  \
# 0              4.0         Campfire       017  Deschutes    2005-02-05
# 1              4.0         Campfire       017  Deschutes    2005-03-05
# 2              4.0         Campfire       017  Deschutes    2005-04-05
# 3              9.0    Miscellaneous       069    Wheeler    2005-03-11
# 4              4.0         Campfire       017  Deschutes    2005-02-16
#
#   CONTAINMENT_DATE
# 0       2005-02-06
# 1       2005-03-05
# 2       2005-04-05
# 3       2005-03-11
# 4       2005-02-16

# %%
#Drop the original columns that contained julian dates
oregon_fires_df.drop(["DISCOVERY_DATE", "CONT_DATE"], axis=1, inplace=True)
oregon_fires_df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 0      32      0028        0.1               A  43.995556 -121.414167
# 1      36      0044        0.1               A  44.043333 -121.386111
# 2      44      0088        0.1               A  43.955556 -121.352222
# 3      47     EARLY        5.0               B  44.911111 -119.696111
# 4      49      0032        0.1               A  43.725278 -121.574167
#
#    FIRE_YEAR  DISCOVERY_DOY  CONT_DOY  STAT_CAUSE_CODE STAT_CAUSE_DESCR  \
# 0       2005             36      37.0              4.0         Campfire
# 1       2005             64      64.0              4.0         Campfire
# 2       2005             95      95.0              4.0         Campfire
# 3       2005             70      70.0              9.0    Miscellaneous
# 4       2005             47      47.0              4.0         Campfire
#
#   FIPS_CODE  FIPS_NAME DISCOVER_DATE CONTAINMENT_DATE
# 0       017  Deschutes    2005-02-05       2005-02-06
# 1       017  Deschutes    2005-03-05       2005-03-05
# 2       017  Deschutes    2005-04-05       2005-04-05
# 3       069    Wheeler    2005-03-11       2005-03-11
# 4       017  Deschutes    2005-02-16       2005-02-16

# %%
# Calculate the number of days that the fires burned
oregon_fires_df["DURATION"] = (oregon_fires_df["CONTAINMENT_DATE"] - oregon_fires_df["DISCOVER_DATE"]).dt.days
oregon_fires_df["DURATION"].value_counts()
# Out:
# 0       42330
# 1       11198
# 2        2458
# 3        1449
# 4         706
#         ...
# 262         1
# 274         1
# 118         1
# 207         1
# 2557        1
# Name: DURATION, Length: 132, dtype: int64

# %%
# Check
oregon_fires_df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 0      32      0028        0.1               A  43.995556 -121.414167
# 1      36      0044        0.1               A  44.043333 -121.386111
# 2      44      0088        0.1               A  43.955556 -121.352222
# 3      47     EARLY        5.0               B  44.911111 -119.696111
# 4      49      0032        0.1               A  43.725278 -121.574167
#
#    FIRE_YEAR  DISCOVERY_DOY  CONT_DOY  STAT_CAUSE_CODE STAT_CAUSE_DESCR  \
# 0       2005             36      37.0              4.0         Campfire
# 1       2005             64      64.0              4.0         Campfire
# 2       2005             95      95.0              4.0         Campfire
# 3       2005             70      70.0              9.0    Miscellaneous
# 4       2005             47      47.0              4.0         Campfire
#
#   FIPS_CODE  FIPS_NAME DISCOVER_DATE CONTAINMENT_DATE  DURATION
# 0       017  Deschutes    2005-02-05       2005-02-06         1
# 1       017  Deschutes    2005-03-05       2005-03-05         0
# 2       017  Deschutes    2005-04-05       2005-04-05         0
# 3       069    Wheeler    2005-03-11       2005-03-11         0
# 4       017  Deschutes    2005-02-16       2005-02-16         0

# %%
oregon_fires_df.dtypes
# Out:
# FOD_ID                       int64
# FIRE_NAME                   object
# FIRE_SIZE                  float64
# FIRE_SIZE_CLASS             object
# LATITUDE                   float64
# LONGITUDE                  float64
# FIRE_YEAR                    int64
# DISCOVERY_DOY                int64
# CONT_DOY                   float64
# STAT_CAUSE_CODE            float64
# STAT_CAUSE_DESCR            object
# FIPS_CODE                   object
# FIPS_NAME                   object
# DISCOVER_DATE       datetime64[ns]
# CONTAINMENT_DATE    datetime64[ns]
# DURATION                     int64
# dtype: object

# %%
#rename FIPS columns to County
oregon_fires_df.rename(columns={"FIPS_CODE": "COUNTY_CODE", "FIPS_NAME":"COUNTY_NAME"}, inplace=True)
oregon_fires_df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 0      32      0028        0.1               A  43.995556 -121.414167
# 1      36      0044        0.1               A  44.043333 -121.386111
# 2      44      0088        0.1               A  43.955556 -121.352222
# 3      47     EARLY        5.0               B  44.911111 -119.696111
# 4      49      0032        0.1               A  43.725278 -121.574167
#
#    FIRE_YEAR  DISCOVERY_DOY  CONT_DOY  STAT_CAUSE_CODE STAT_CAUSE_DESCR  \
# 0       2005             36      37.0              4.0         Campfire
# 1       2005             64      64.0              4.0         Campfire
# 2       2005             95      95.0              4.0         Campfire
# 3       2005             70      70.0              9.0    Miscellaneous
# 4       2005             47      47.0              4.0         Campfire
#
#   COUNTY_CODE COUNTY_NAME DISCOVER_DATE CONTAINMENT_DATE  DURATION
# 0         017   Deschutes    2005-02-05       2005-02-06         1
# 1         017   Deschutes    2005-03-05       2005-03-05         0
# 2         017   Deschutes    2005-04-05       2005-04-05         0
# 3         069     Wheeler    2005-03-11       2005-03-11         0
# 4         017   Deschutes    2005-02-16       2005-02-16         0

# %%
#Convert column names to lower case and rename discover_date to discovery_date
oregon_fires_df.rename(columns={"DISCOVER_DATE": "DISCOVERY_DATE"}, inplace=True)
oregon_fires_df.rename(str.lower, axis='columns', inplace=True)
oregon_fires_df
# Out:
#           fod_id              fire_name  fire_size fire_size_class   latitude  \
# 0             32                   0028       0.10               A  43.995556
# 1             36                   0044       0.10               A  44.043333
# 2             44                   0088       0.10               A  43.955556
# 3             47                  EARLY       5.00               B  44.911111
# 4             49                   0032       0.10               A  43.725278
# ...          ...                    ...        ...             ...        ...
# 61081  300273801  OLD PORTLAND/KASTER#3       0.01               A  45.850470
# 61082  300273869          WINHURST LANE       0.10               A  43.090000
# 61083  300273935           MUNSEL CREEK       0.01               A  43.971670
# 61084  300274008         MP 240 HWY 101       0.01               A  43.343330
# 61085  300276174          CHINA HAT 698       0.10               A  44.003330
#
#         longitude  fire_year  discovery_doy  cont_doy  stat_cause_code  \
# 0     -121.414167       2005             36      37.0              4.0
# 1     -121.386111       2005             64      64.0              4.0
# 2     -121.352222       2005             95      95.0              4.0
# 3     -119.696111       2005             70      70.0              9.0
# 4     -121.574167       2005             47      47.0              4.0
# ...           ...        ...            ...       ...              ...
# 61081 -122.813530       2015            270     270.0              9.0
# 61082 -124.390280       2015            271     272.0              9.0
# 61083 -124.100280       2015            275     275.0              9.0
# 61084 -124.197500       2015            277     278.0              9.0
# 61085 -121.321670       2015            335     338.0              9.0
#
#       stat_cause_descr county_code county_name discovery_date  \
# 0             Campfire         017   Deschutes     2005-02-05
# 1             Campfire         017   Deschutes     2005-03-05
# 2             Campfire         017   Deschutes     2005-04-05
# 3        Miscellaneous         069     Wheeler     2005-03-11
# 4             Campfire         017   Deschutes     2005-02-16
# ...                ...         ...         ...            ...
# 61081    Miscellaneous         009    Columbia     2015-09-27
# 61082    Miscellaneous         011        Coos     2015-09-28
# 61083    Miscellaneous         039        Lane     2015-10-02
# 61084    Miscellaneous         011        Coos     2015-10-04
# 61085    Miscellaneous         017   Deschutes     2015-12-01
#
#       containment_date  duration
# 0           2005-02-06         1
# 1           2005-03-05         0
# 2           2005-04-05         0
# 3           2005-03-11         0
# 4           2005-02-16         0
# ...                ...       ...
# 61081       2015-09-27         0
# 61082       2015-09-29         1
# 61083       2015-10-02         0
# 61084       2015-10-05         1
# 61085       2015-12-04         3
#
# [60751 rows x 16 columns]

# %%
#write dataframe to a csv file in the Resource folder
os.makedirs('Resources', exist_ok=True)
oregon_fires_df.to_csv('Resources/oregon_fires.csv',index=False)

# %%
#Create a dataFrame of fire causes
Fire_Causes = oregon_fires_df[["stat_cause_code", "stat_cause_descr"]].drop_duplicates()
Fire_Causes.sort_values(by=["stat_cause_code"], inplace=True)

Fire_Causes.set_index("stat_cause_code", inplace=True)
Fire_Causes
# Out:
#                   stat_cause_descr
# stat_cause_code
# 1.0                      Lightning
# 2.0                  Equipment Use
# 3.0                        Smoking
# 4.0                       Campfire
# 5.0                 Debris Burning
# 6.0                       Railroad
# 7.0                          Arson
# 8.0                       Children
# 9.0                  Miscellaneous
# 10.0                     Fireworks
# 11.0                     Powerline
# 12.0                     Structure
# 13.0             Missing/Undefined

# %%
# Create a dataFrame of Counties
Counties = oregon_fires_df[["county_code", "county_name"]].drop_duplicates()
Counties.sort_values(by=["county_code"], inplace=True)

Counties.set_index("county_code", inplace=True)
Counties
# Out:
#             county_name
# county_code
# 001               Baker
# 003              Benton
# 005           Clackamas
# 007             Clatsop
# 009            Columbia
# 011                Coos
# 013               Crook
# 015               Curry
# 017           Deschutes
# 019             Douglas
# 021             Gilliam
# 023               Grant
# 025              Harney
# 027          Hood River
# 029             Jackson
# 031           Jefferson
# 033           Josephine
# 035             Klamath
# 037                Lake
# 039                Lane
# 041             Lincoln
# 043                Linn
# 045             Malheur
# 047              Marion
# 049              Morrow
# 051           Multnomah
# 053                Polk
# 055             Sherman
# 057           Tillamook
# 059            Umatilla
# 061               Union
# 063             Wallowa
# 065               Wasco
# 067          Washington
# 069             Wheeler
# 071             Yamhill
# NaN                None

# %%
# Create dataFrame of Fire_Names
Fire_Names = oregon_fires_df[["fod_id", "fire_name"]]
Fire_Names.set_index("fod_id", inplace=True)

# %%
Fire_Names
# Out:
#                        fire_name
# fod_id
# 32                          0028
# 36                          0044
# 44                          0088
# 47                         EARLY
# 49                          0032
# ...                          ...
# 300273801  OLD PORTLAND/KASTER#3
# 300273869          WINHURST LANE
# 300273935           MUNSEL CREEK
# 300274008         MP 240 HWY 101
# 300276174          CHINA HAT 698
#
# [60751 rows x 1 columns]

# %%
# Create a dataFrame of all the rest of the fire information in order to populate the Fires table
Fires = oregon_fires_df[["fod_id", "fire_size", "fire_size_class", "latitude", "longitude", "fire_year", "discovery_doy", "cont_doy", "discovery_date", "containment_date", "duration", "county_code", "stat_cause_code"]]
Fires.set_index("fod_id", inplace=True)
Fires.head()
# Out:
#         fire_size fire_size_class   latitude   longitude  fire_year  \
# fod_id
# 32            0.1               A  43.995556 -121.414167       2005
# 36            0.1               A  44.043333 -121.386111       2005
# 44            0.1               A  43.955556 -121.352222       2005
# 47            5.0               B  44.911111 -119.696111       2005
# 49            0.1               A  43.725278 -121.574167       2005
#
#         discovery_doy  cont_doy discovery_date containment_date  duration  \
# fod_id
# 32                 36      37.0     2005-02-05       2005-02-06         1
# 36                 64      64.0     2005-03-05       2005-03-05         0
# 44                 95      95.0     2005-04-05       2005-04-05         0
# 47                 70      70.0     2005-03-11       2005-03-11         0
# 49                 47      47.0     2005-02-16       2005-02-16         0
#
#        county_code  stat_cause_code
# fod_id
# 32             017              4.0
# 36             017              4.0
# 44             017              4.0
# 47             069              9.0
# 49             017              4.0

# %%
# Connect to the RDS postgres db and add the dataframes to postgres
db_string = f"postgresql://postgres:{db_password}@fires.crlyg1rjxxj2.us-west-2.rds.amazonaws.com:5432/postgres"
engine = create_engine(db_string)

# %%
Fire_Causes.to_sql(name="fire_causes", if_exists="replace", con=engine)

# %%
Counties.to_sql(name="counties", if_exists="replace", con=engine)

# %%
Fire_Names.to_sql(name="fire_names", if_exists="replace", con=engine)

# %%
Fires.to_sql(name="fires", if_exists="replace", con=engine)
